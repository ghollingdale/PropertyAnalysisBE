# %%
# Import modules
import numpy as np
import pandas as pd

# %%
# Load csv & display some basic details
properties = pd.read_csv('properties.csv', header=0)
display(properties.head())
display(properties.tail())
display(properties.shape)
display(properties.columns.tolist())
# Out:
#          id type of property subtype of property    locality         province  \
# 0  10679324            HOUSE               HOUSE     Seraing            Liège
# 1  10679325            HOUSE               HOUSE        Vise            Liège
# 2  10679351            HOUSE               VILLA   Vilvoorde  Flemish Brabant
# 3  10679090            HOUSE               HOUSE  Oudenaarde    East Flanders
# 4  10678835            HOUSE               HOUSE     Dilbeek  Flemish Brabant
#
#    postalCode   price      type of sale  number of bedrooms  living area  ...  \
# 0        4100  159000  residential_sale                   3           14  ...
# 1        4600  229000  residential_sale                   3           19  ...
# 2        1800  430000  residential_sale                   3           17  ...
# 3        9700  439000  residential_sale                   2           21  ...
# 4        1700  529000  residential_sale                   4           29  ...
#
# ...

# %%
localities = properties['locality'].unique()

printed_locations = set()

for location in localities:
    if location not in printed_locations:
        print(location)
        printed_locations.add(location)
# Out:
# Seraing
# Vise
# Vilvoorde
# Oudenaarde
# Dilbeek
# Gent
# Ronse
# Liege
# Braine-l'Alleud Ophain-Bois-Seigneur-Isaac
# Watermael-Boitsfort
# Zaventem
# Antwerp
# Schaerbeek
# Saint-Gilles
# Anderlecht
# Wavre
# Bouge
# Andenne
# Braine-l'Alleud
# Sprimont
# ZERKEGEM
# Ottignies-Louvain-la-Neuve Céroux-Mousty
# Nieuwpoort
# Etterbeek
# Tervuren
# Saint-Nicolas
# Wichelen Serskamp
# Liège
# SINT-LAMBRECHTS-WOLUWE
# Deurne
# Uccle
# Waterloo
# Knokke-Heist
# Arlon
# Aubange
# GENTBRUGGE
# Ixelles
# Leuven
# Mechelen
# ROCOURT
# Sint-Pieters-Woluwe
# Brussels City
# Woluwe-Saint-Pierre
# Woluwe-Saint-Lambert
# Borgerhout
# Lasne
# Geraardsbergen
# Bruxelles
# Ninove
# Linkebeek
# Lede
# Russeignies
# Dendermonde
# Asse Zellik
# Drogenbos
# Auderghem
# Huy
# Rixensart
# Beersel
# Wezembeek-Oppem
# Schilde
# Blankenberge
# Gent Sint-Denijs-Westrem
# Evere
# Embourg
# Molenbeek-Saint-Jean
# Schoten
# Jette
# Drongen
# Brussels
# Rixensart Genval
# Mettet
# FRAIRE
# Gooik
# Herent
# ...
