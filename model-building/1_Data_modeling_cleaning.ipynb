# %%
# Autoload module updates
# %load_ext autoreload
# %autoreload 2

# Import modules
import numpy as np
import pandas as pd
import sklearn
import sys
sys.path.insert(0, '../')
import src.cleanup as cleanup
properties = pd.read_csv('..\data\cleaned_output.csv', skip_blank_lines=True)

# %%
# Read dataframe

# %% [markdown]
# # Data Cleaning 2.0
# After analysing my data, I want to use it for predicts. Before building my model I need to further clean my data of
# * Any NaN values
# * Any string values
# * Any duplicates
#
# I have already confirmed that there are no duplicates, so the first thing to deal with will be strings, then NaNs.

# %% [markdown]
# Columns `id` and `type of sale`  need dropping since these contain useless data. The `state of the building` column will be converted to binary with fully renovated properties processed as 1s, and properties that need any sort of renovation processed as 0s.

# %%
columns = ['id','type of sale']
properties = cleanup.drop_column(properties, columns)

# %% [markdown]
# Now clean the renovation data:

# %%
# Replace specific value in a given column with new_value
def replace_col_value(df, column, value, new_value):
    for index, row in df.iterrows():
        if row[column] == value:
            df.at[index, column] = new_value
    return df

# %%
properties = cleanup.replace_col_value(properties, 'state of the building', 'needs renovating', 0)
properties = cleanup.replace_col_value(properties, 'state of the building', '0', 0)

renovated = ['just_renovated', 'as_new', 'good']
for i in renovated:
    properties = cleanup.replace_col_value(properties, 'state of the building', i, 1)

cleanup.unique_df_values(properties)
# Out:
# state of the building
# 1    8278
# 0    3714
# Name: count, dtype: int64

# %% [markdown]
# Checking for NaNs:

# %%
properties.head()
# Out:
#   type of property subtype of property    province       locality  postalCode  \
# 0            HOUSE               HOUSE       Liège  Saint-Nicolas      4420.0
# 1            HOUSE              CHALET  Luxembourg         DURBUY      6940.0
# 2        APARTMENT           APARTMENT     Hainaut    La Louviere      7110.0
# 3            HOUSE               HOUSE       Liège       Flémalle      4400.0
# 4            HOUSE               HOUSE       Liège   Liège Wandre      4020.0
#
#      price  number of bedrooms  living area  fully equipped kitchen  \
# 0  20000.0                   3           38                     1.0
# 1  22000.0                   2            0                     NaN
# 2  39000.0                   1            0                     0.0
# 3  40000.0                   2           21                     0.0
# 4  59000.0                   4           29                     0.0
#
#    furnished  open fire  terrace  terrace area  garden  garden area  \
# 0        0.0          0      1.0           NaN     NaN          NaN
# 1        0.0          0      1.0          15.0     NaN          NaN
# 2        0.0          0      NaN           NaN     NaN          NaN
# 3        0.0          0      NaN           NaN     NaN          NaN
# 4        0.0          0      NaN           NaN     NaN          NaN
#
#    total property area  total land area  number of facades  swimming pool  \
# 0                206.0            194.0                NaN              0
# 1                 40.0            200.0                4.0              0
# 2                 44.0              0.0                2.0              0
# 3                106.0            110.0                3.0              0
# 4                144.0             80.0                2.0              0
#
#   state of the building
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %% [markdown]
# Replace NaNs in terrace/garden with 1s if terrace area exists:

# %%
properties = cleanup.check_for_adjascent_data(properties, 'terrace area', 'terrace', 1)
properties = cleanup.check_for_adjascent_data(properties, 'garden area', 'garden', 1)

# %% [markdown]
# Replace other Garden and Terrace Nans with zeroes:

# %%
properties.head()
properties = cleanup.sort_by_column(properties, 'living area')
properties.head()
# Out:
#      type of property subtype of property         province           locality  \
# 5995            HOUSE               HOUSE  Flemish Brabant             ZICHEM
# 6689            HOUSE               HOUSE          Antwerp             Nijlen
# 6678        APARTMENT           APARTMENT    West Flanders         Nieuwpoort
# 6668            HOUSE               HOUSE          Antwerp  Heist-op-den-Berg
# 6667            HOUSE               HOUSE    West Flanders          Oudenburg
#
#       postalCode     price  number of bedrooms  living area  \
# 5995      3271.0  350000.0                   3            0
# 6689      2560.0  389000.0                   3            0
# 6678      8620.0  389000.0                   2            0
# 6668      2220.0  389000.0                   3            0
# 6667      8460.0  389000.0                   3            0
#
#       fully equipped kitchen  furnished  open fire  terrace  terrace area  \
# 5995                     1.0        NaN          1      1.0          25.0
# 6689                     1.0        0.0          0      1.0          40.0
# 6678                     1.0        0.0          0      NaN           NaN
# 6668                     NaN        NaN          1      1.0           NaN
# 6667                     1.0        NaN          1      NaN           NaN
#
#       garden  garden area  total property area  total land area  \
# 5995     1.0          NaN                140.0           2590.0
# 6689     1.0        260.0                160.0            570.0
# 6678     1.0         75.0                100.0              NaN
# 6668     1.0          NaN                151.0            792.0
# 6667     NaN          NaN                133.0            347.0
#
#       number of facades  swimming pool state of the building
# 5995                4.0              0                     0
# 6689                4.0              0                     1
# 6678                4.0              0                     1
# 6668                4.0              0                     0
# 6667                3.0              0                     1

# %% [markdown]
# Replace `furnished`, `open fire`, `terrace`, `terrace area`, `garden` and `garden area` nans with 0s.

# %%
columns = ['furnished', 'open fire', 'terrace', 'terrace area', 'garden', 'garden area']

for i in columns:
    properties = cleanup.replace_nan(properties, i)
properties.head()
# Out:
#      type of property subtype of property         province           locality  \
# 5995            HOUSE               HOUSE  Flemish Brabant             ZICHEM
# 6689            HOUSE               HOUSE          Antwerp             Nijlen
# 6678        APARTMENT           APARTMENT    West Flanders         Nieuwpoort
# 6668            HOUSE               HOUSE          Antwerp  Heist-op-den-Berg
# 6667            HOUSE               HOUSE    West Flanders          Oudenburg
#
#       postalCode     price  number of bedrooms  living area  \
# 5995      3271.0  350000.0                   3            0
# 6689      2560.0  389000.0                   3            0
# 6678      8620.0  389000.0                   2            0
# 6668      2220.0  389000.0                   3            0
# 6667      8460.0  389000.0                   3            0
#
#       fully equipped kitchen  furnished  open fire  terrace  terrace area  \
# 5995                     1.0        0.0          1      1.0          25.0
# 6689                     1.0        0.0          0      1.0          40.0
# 6678                     1.0        0.0          0      0.0           0.0
# 6668                     NaN        0.0          1      1.0           0.0
# 6667                     1.0        0.0          1      0.0           0.0
#
#       garden  garden area  total property area  total land area  \
# 5995     1.0          0.0                140.0           2590.0
# 6689     1.0        260.0                160.0            570.0
# 6678     1.0         75.0                100.0              NaN
# 6668     1.0          0.0                151.0            792.0
# 6667     0.0          0.0                133.0            347.0
#
#       number of facades  swimming pool state of the building
# 5995                4.0              0                     0
# 6689                4.0              0                     1
# 6678                4.0              0                     1
# 6668                4.0              0                     0
# 6667                3.0              0                     1

# %% [markdown]
# Delete rows that are missing Kitchen Data

# %%
display(properties.shape)
properties = properties.dropna(subset=['fully equipped kitchen', 'total land area', 'total property area', 'number of facades'])
# Out:
# (11992, 20)

# %%
nan_counts = properties.isnull().sum()
print(nan_counts)
# Out:
# type of property          0
# subtype of property       0
# province                  0
# locality                  0
# postalCode                0
# price                     0
# number of bedrooms        0
# living area               0
# fully equipped kitchen    0
# furnished                 0
# open fire                 0
# terrace                   0
# terrace area              0
# garden                    0
# garden area               0
# total property area       0
# total land area           0
# number of facades         0
# swimming pool             0
# state of the building     0
# dtype: int64

# %%
cleanup.column_type_float(properties)
# Out:
#       type of property subtype of property         province  \
# 5995             HOUSE               HOUSE  Flemish Brabant
# 6689             HOUSE               HOUSE          Antwerp
# 6667             HOUSE               HOUSE    West Flanders
# 6666             HOUSE               HOUSE    West Flanders
# 6665             HOUSE               HOUSE    West Flanders
# ...                ...                 ...              ...
# 9291         APARTMENT                LOFT            Liège
# 11102        APARTMENT           APARTMENT         Brussels
# 3299             HOUSE               HOUSE          Hainaut
# 11317            HOUSE               HOUSE         Brussels
# 9495             HOUSE               HOUSE         Brussels
#
#                   locality  postalCode      price  number of bedrooms  \
# 5995                ZICHEM      3271.0   350000.0                   3
# 6689                Nijlen      2560.0   389000.0                   3
# 6667             Oudenburg      8460.0   389000.0                   3
# 6666                Brugge      8000.0   389000.0                   6
# 6665          Blankenberge      8370.0   389000.0                   3
# ...                    ...         ...        ...                 ...
# 9291                 Liege      4020.0   599000.0                   3
# 11102               Forest      1190.0  1200000.0                   3
# 3299                Luttre      6238.0   249900.0                   3
# 11317           Schaerbeek      1030.0  1400000.0                   8
# 9495   Sint-Agatha-Berchem      1082.0   645000.0                   4
#
#        living area  fully equipped kitchen  furnished  open fire  terrace  \
# 5995             0                     1.0        0.0          1      1.0
# 6689             0                     1.0        0.0          0      1.0
# 6667             0                     1.0        0.0          1      0.0
# 6666             0                     1.0        0.0          0      1.0
# 6665             0                     1.0        1.0          1      1.0
# ...            ...                     ...        ...        ...      ...
# 9291           180                     1.0        0.0          0      1.0
# 11102          210                     1.0        0.0          0      0.0
# 3299           378                     1.0        0.0          0      1.0
# 11317          389                     1.0        0.0          0      1.0
# 9495          3558                     1.0        0.0          0      1.0
#
#        terrace area  garden  garden area  total property area  \
# 5995           25.0     1.0          0.0                140.0
# 6689           40.0     1.0        260.0                160.0
# 6667            0.0     0.0          0.0                133.0
# 6666            0.0     1.0        119.0                210.0
# 6665           17.0     0.0          0.0                222.0
# ...             ...     ...          ...                  ...
# 9291            0.0     1.0        107.0                333.0
# 11102           0.0     0.0          0.0                315.0
# 3299           40.0     1.0         50.0                260.0
# 11317           0.0     1.0        128.0                488.0
# 9495            0.0     1.0        245.0                268.0
#
#        total land area  number of facades  swimming pool state of the building
# 5995            2590.0                4.0              0                     0
# 6689             570.0                4.0              0                     1
# 6667             347.0                3.0              0                     1
# 6666             220.0                2.0              0                     0
# 6665             111.0                2.0              0                     1
# ...                ...                ...            ...                   ...
# 9291               0.0                2.0              0                     1
# 11102              0.0                2.0              0                     1
# 3299             180.0                3.0              0                     1
# 11317            305.0                2.0              0                     1
# 9495             245.0                3.0              0                     1
#
# [6347 rows x 20 columns]

# %%
properties.to_csv('..\data\cleaned_output_2.csv', index=False)
