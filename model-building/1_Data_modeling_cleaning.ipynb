# %%
# Autoload module updates
# %load_ext autoreload
# %autoreload 2

# Import modules
import numpy as np
import pandas as pd
import sklearn
import sys
sys.path.insert(0, '../')
import src.cleanup as cleanup
properties = pd.read_csv('..\data\cleaned_output.csv', skip_blank_lines=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Read dataframe

# %% [markdown]
# # Data Cleaning 2.0
# After analysing my data, I want to use it for predicts. Before building my model I need to further clean my data of
# * Any NaN values
# * Any string values
# * Any duplicates
#
# I have already confirmed that there are no duplicates, so the first thing to deal with will be strings, then NaNs.

# %% [markdown]
# Columns `id` and `type of sale`  need dropping since these contain useless data. The `state of the building` column will be converted to binary with fully renovated properties processed as 1s, and properties that need any sort of renovation processed as 0s.

# %%
columns = ['id','type_of-sale']
properties = cleanup.drop_column(properties, columns)

# %% [markdown]
# Now clean the renovation data:

# %%
# Replace specific value in a given column with new_value
def replace_col_value(df, column, value, new_value):
    for index, row in df.iterrows():
        if row[column] == value:
            df.at[index, column] = new_value
    return df

# %%
properties = cleanup.replace_col_value(properties, 'state_of_the_building', 'needs renovating', 0)
properties = cleanup.replace_col_value(properties, 'state_of_the_building', '0', 0)

renovated = ['just_renovated', 'as_new', 'good']
for i in renovated:
    properties = cleanup.replace_col_value(properties, 'state_of_the_building', i, 1)

cleanup.unique_df_values(properties)
# Out:
# state_of_the_building
# 1    8278
# 0    3714
# Name: count, dtype: int64

# %% [markdown]
# Checking for NaNs:

# %%
properties.head()
# Out:
#          id type_of_property subtype_of_property    province       locality  \
# 0  10492614            HOUSE               HOUSE       Liège  Saint-Nicolas
# 1  10664145            HOUSE              CHALET  Luxembourg         DURBUY
# 2  10578200        APARTMENT           APARTMENT     Hainaut    La Louviere
# 3  10248737            HOUSE               HOUSE       Liège       Flémalle
# 4  10576318            HOUSE               HOUSE       Liège   Liège Wandre
#
#    postalCode    price  number_of_bedrooms  living_area  \
# 0      4420.0  20000.0                 3.0         38.0
# 1      6940.0  22000.0                 2.0          0.0
# 2      7110.0  39000.0                 1.0          0.0
# 3      4400.0  40000.0                 2.0         21.0
# 4      4020.0  59000.0                 4.0         29.0
#
#    fully_equipped_kitchen  ...  open_fire  terrace  terrace_area  garden  \
# 0                     1.0  ...        0.0      1.0           NaN     NaN
# 1                     NaN  ...        0.0      1.0          15.0     NaN
# 2                     0.0  ...        0.0      NaN           NaN     NaN
# 3                     0.0  ...        0.0      NaN           NaN     NaN
# 4                     0.0  ...        0.0      NaN           NaN     NaN
#
#    garden_area  total_property_area  total_land_area  number_of_facades  \
# 0          NaN                206.0            194.0                NaN
# 1          NaN                 40.0            200.0                4.0
# 2          NaN                 44.0              0.0                2.0
# 3          NaN                106.0            110.0                3.0
# 4          NaN                144.0             80.0                2.0
#
#    swimming_pool  state_of_the_building
# 0            0.0                      1
# 1            0.0                      0
# 2            0.0                      0
# 3            0.0                      0
# 4            0.0                      0
#
# [5 rows x 21 columns]

# %% [markdown]
# Replace NaNs in terrace/garden with 1s if terrace area exists:

# %%
properties = cleanup.check_for_adjascent_data(properties, 'terrace_area', 'terrace', 1)
properties = cleanup.check_for_adjascent_data(properties, 'garden_area', 'garden', 1)
0
# Out:
# 0

# %% [markdown]
# Replace other Garden and Terrace Nans with zeroes:

# %%
properties.head()
properties = cleanup.sort_by_column(properties, 'living_area')
properties.head()
# Out:
#             id type_of_property subtype_of_property         province  \
# 5995  10559233            HOUSE               HOUSE  Flemish Brabant
# 6689  10673158            HOUSE               HOUSE          Antwerp
# 6678  10385356        APARTMENT           APARTMENT    West Flanders
# 6668  10678328            HOUSE               HOUSE          Antwerp
# 6667  10470833            HOUSE               HOUSE    West Flanders
#
#                locality  postalCode     price  number_of_bedrooms  \
# 5995             ZICHEM      3271.0  350000.0                 3.0
# 6689             Nijlen      2560.0  389000.0                 3.0
# 6678         Nieuwpoort      8620.0  389000.0                 2.0
# 6668  Heist-op-den-Berg      2220.0  389000.0                 3.0
# 6667          Oudenburg      8460.0  389000.0                 3.0
#
#       living_area  fully_equipped_kitchen  ...  open_fire  terrace  \
# 5995          0.0                     1.0  ...        1.0      1.0
# 6689          0.0                     1.0  ...        0.0      1.0
# 6678          0.0                     1.0  ...        0.0      NaN
# 6668          0.0                     NaN  ...        1.0      1.0
# 6667          0.0                     1.0  ...        1.0      NaN
#
#       terrace_area  garden  garden_area  total_property_area  total_land_area  \
# 5995          25.0     1.0          NaN                140.0           2590.0
# 6689          40.0     1.0        260.0                160.0            570.0
# 6678           NaN     1.0         75.0                100.0              NaN
# 6668           NaN     1.0          NaN                151.0            792.0
# 6667           NaN     NaN          NaN                133.0            347.0
#
#       number_of_facades  swimming_pool  state_of_the_building
# 5995                4.0            NaN                      0
# 6689                4.0            NaN                      1
# 6678                4.0            0.0                      1
# 6668                4.0            NaN                      0
# 6667                3.0            NaN                      1
#
# [5 rows x 21 columns]

# %% [markdown]
# Replace `furnished`, `open fire`, `terrace`, `terrace area`, `garden`, `garden area` and `swimming pool` nans with 0s.

# %%
columns = ['furnished', 'open_fire', 'terrace', 'terrace_area', 'garden', 'garden_area', 'swimming_pool']

for i in columns:
    properties = cleanup.replace_nan(properties, i)
properties.head()
# Out:
#             id type_of_property subtype_of_property         province  \
# 5995  10559233            HOUSE               HOUSE  Flemish Brabant
# 6689  10673158            HOUSE               HOUSE          Antwerp
# 6678  10385356        APARTMENT           APARTMENT    West Flanders
# 6668  10678328            HOUSE               HOUSE          Antwerp
# 6667  10470833            HOUSE               HOUSE    West Flanders
#
#                locality  postalCode     price  number_of_bedrooms  \
# 5995             ZICHEM      3271.0  350000.0                 3.0
# 6689             Nijlen      2560.0  389000.0                 3.0
# 6678         Nieuwpoort      8620.0  389000.0                 2.0
# 6668  Heist-op-den-Berg      2220.0  389000.0                 3.0
# 6667          Oudenburg      8460.0  389000.0                 3.0
#
#       living_area  fully_equipped_kitchen  ...  open_fire  terrace  \
# 5995          0.0                     1.0  ...        1.0      1.0
# 6689          0.0                     1.0  ...        0.0      1.0
# 6678          0.0                     1.0  ...        0.0      0.0
# 6668          0.0                     NaN  ...        1.0      1.0
# 6667          0.0                     1.0  ...        1.0      0.0
#
#       terrace_area  garden  garden_area  total_property_area  total_land_area  \
# 5995          25.0     1.0          0.0                140.0           2590.0
# 6689          40.0     1.0        260.0                160.0            570.0
# 6678           0.0     1.0         75.0                100.0              NaN
# 6668           0.0     1.0          0.0                151.0            792.0
# 6667           0.0     0.0          0.0                133.0            347.0
#
#       number_of_facades  swimming_pool  state_of_the_building
# 5995                4.0            0.0                      0
# 6689                4.0            0.0                      1
# 6678                4.0            0.0                      1
# 6668                4.0            0.0                      0
# 6667                3.0            0.0                      1
#
# [5 rows x 21 columns]

# %% [markdown]
# Delete rows that are missing Kitchen Data

# %%
display(properties.shape)
properties = properties.dropna(subset=['fully_equipped_kitchen', 'total_land_area', 'total_property_area', 'number_of_facades'])
# Out:
# (11992, 21)

# %%
nan_counts = properties.isnull().sum()
print(nan_counts)
# Out:
# id                        0
# type_of_property          0
# subtype_of_property       0
# province                  0
# locality                  0
# postalCode                0
# price                     0
# number_of_bedrooms        0
# living_area               0
# fully_equipped_kitchen    0
# furnished                 0
# open_fire                 0
# terrace                   0
# terrace_area              0
# garden                    0
# garden_area               0
# total_property_area       0
# total_land_area           0
# number_of_facades         0
# swimming_pool             0
# state_of_the_building     0
# dtype: int64

# %%
cleanup.column_type_float(properties)
# Out:
#                id type_of_property subtype_of_property         province  \
# 5995   10559233.0            HOUSE               HOUSE  Flemish Brabant
# 6689   10673158.0            HOUSE               HOUSE          Antwerp
# 6667   10470833.0            HOUSE               HOUSE    West Flanders
# 6666   10560493.0            HOUSE               HOUSE    West Flanders
# 6665   10452028.0            HOUSE               HOUSE    West Flanders
# ...           ...              ...                 ...              ...
# 9291   10395316.0        APARTMENT                LOFT            Liège
# 11102   9553014.0        APARTMENT           APARTMENT         Brussels
# 3299   10337514.0            HOUSE               HOUSE          Hainaut
# 11317  10666309.0            HOUSE               HOUSE         Brussels
# 9495   10557452.0            HOUSE               HOUSE         Brussels
#
#                   locality  postalCode      price  number_of_bedrooms  \
# 5995                ZICHEM      3271.0   350000.0                 3.0
# 6689                Nijlen      2560.0   389000.0                 3.0
# 6667             Oudenburg      8460.0   389000.0                 3.0
# 6666                Brugge      8000.0   389000.0                 6.0
# 6665          Blankenberge      8370.0   389000.0                 3.0
# ...                    ...         ...        ...                 ...
# 9291                 Liege      4020.0   599000.0                 3.0
# 11102               Forest      1190.0  1200000.0                 3.0
# 3299                Luttre      6238.0   249900.0                 3.0
# 11317           Schaerbeek      1030.0  1400000.0                 8.0
# 9495   Sint-Agatha-Berchem      1082.0   645000.0                 4.0
#
#        living_area  fully_equipped_kitchen  ...  open_fire  terrace  \
# 5995           0.0                     1.0  ...        1.0      1.0
# 6689           0.0                     1.0  ...        0.0      1.0
# 6667           0.0                     1.0  ...        1.0      0.0
# 6666           0.0                     1.0  ...        0.0      1.0
# 6665           0.0                     1.0  ...        1.0      1.0
# ...            ...                     ...  ...        ...      ...
# 9291         180.0                     1.0  ...        0.0      1.0
# 11102        210.0                     1.0  ...        0.0      0.0
# 3299         378.0                     1.0  ...        0.0      1.0
# 11317        389.0                     1.0  ...        0.0      1.0
# 9495        3558.0                     1.0  ...        0.0      1.0
#
#        terrace_area  garden  garden_area  total_property_area  \
# 5995           25.0     1.0          0.0                140.0
# 6689           40.0     1.0        260.0                160.0
# 6667            0.0     0.0          0.0                133.0
# 6666            0.0     1.0        119.0                210.0
# 6665           17.0     0.0          0.0                222.0
# ...             ...     ...          ...                  ...
# 9291            0.0     1.0        107.0                333.0
# 11102           0.0     0.0          0.0                315.0
# 3299           40.0     1.0         50.0                260.0
# 11317           0.0     1.0        128.0                488.0
# 9495            0.0     1.0        245.0                268.0
#
#        total_land_area  number_of_facades  swimming_pool  \
# 5995            2590.0                4.0            0.0
# 6689             570.0                4.0            0.0
# 6667             347.0                3.0            0.0
# 6666             220.0                2.0            0.0
# 6665             111.0                2.0            0.0
# ...                ...                ...            ...
# 9291               0.0                2.0            0.0
# 11102              0.0                2.0            0.0
# 3299             180.0                3.0            0.0
# 11317            305.0                2.0            0.0
# 9495             245.0                3.0            0.0
#
#        state_of_the_building
# 5995                       0
# 6689                       1
# 6667                       1
# 6666                       0
# 6665                       1
# ...                      ...
# 9291                       1
# 11102                      1
# 3299                       1
# 11317                      1
# 9495                       1
#
# [6347 rows x 21 columns]

# %%
properties.to_csv('..\data\cleaned_output_modeling.csv', index=False)
